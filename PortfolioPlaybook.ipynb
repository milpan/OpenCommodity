# %% [markdown]
# # Portfolio Management Tools

# %% [markdown]
# This notebook demonstrates building an example portfolio, and calculating metrics such as the sharpe ratio.

# %%
from tools import *
from strategies import *
from metrics import *
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Define Symbols of which to Optimize (let's for example: use 3 metals)
Symbol = ['SI=F', 'GC=F', 'PL=F', 'URA']
#Weighting needs to be fixed to scale to portfolio value
TotalInvestment = 10000
Weight = [0.3,0.2,0.1,0.4]
symbolhistory = []
#Pull the Data
for commodity in Symbol:
    symbolhistory.append(pull_symbol(commodity, "10y", "1d"))
# Out:
# Pulling Information on the Symbol SI=F/n
# Pulling Information on the Symbol GC=F/n
# Pulling Information on the Symbol PL=F/n
# Pulling Information on the Symbol URA/n

# %% [markdown]
# ## Calculate the historical sharpe ratio

# %%
OurSharpe = calculate_sharpe(symbolhistory, Symbol)

# %% [markdown]
# Plot the Sharpe Ratios in our Example Together

# %% [markdown]
# TO DO Next -> Monte Carlo Simulation to find Optimal Sharpe Ratio

# %%
portfolio_value(symbolhistory, [x*TotalInvestment for x in Weight], Symbol)
# Out:
# Date
# 2011-10-03    5.058643e+06
# 2011-10-04    4.926628e+06
# 2011-10-05    5.002426e+06
# 2011-10-06    5.062354e+06
# 2011-10-07    5.009140e+06
#                   ...
# 2021-09-27    4.648011e+06
# 2021-09-28    4.594210e+06
# 2021-09-29    4.544997e+06
# 2021-09-30    4.632723e+06
# 2021-10-01    4.650750e+06
# Name: Close, Length: 2517, dtype: float64

# %%
print(generate_random_weights(Weight))
# Out:
# [[0.13344329 0.20243709 0.09298102 0.5711386 ]]

# %%
efficient_frontier(symbolhistory, Weight, Symbol, 10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-349239dd0a7a> in <module>
# ----> 1 efficient_frontier(symbolhistory, Weight, Symbol, 10)
#
# ~\PythonProjects\OpenCommodities\strategies\montecarlo.py in efficient_frontier(list_history, list_weights, symbol_name, n_iterations)
#      35         newWeights = generate_random_weights(list_weights)
#      36         #Calculate the portfolio history
# ---> 37         totalHistory = portfolio_value(list_history, newWeights, symbol_name)
#      38         portfolioValue.append(totalHistory)
#      39     return portfolioValue;
#
# ~\PythonProjects\OpenCommodities\strategies\montecarlo.py in portfolio_value(list_history, list_weights, symbol_name)
#      25         close_price = list_history[i]['Close']
#      26         weight = list_weights[i]
# ---> 27         TotalValue.append(close_price*weight)
# ...
